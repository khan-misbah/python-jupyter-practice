# %%
class Library:
    def __init__(self,list,name):
        self.bookslist = list
        self.name = name
        self.lendDict = {}
    def displayBooks(self):
        print("we have many books in library :",self.name)
        for book in self.bookslist:
            print(book)
    def lendBook(self,user,book):
        if book not in self.lendDict.keys():
                self.lendDict.update({book:user})
                print("lender-book database has been updated. you can take it")
        else:
            print("book is already taken by:", {self.lendDict[book]})
            
    def returnBook(self,book):
        self.lendDict.pop(book)
        
# if __name__ == '__main__':
    code = Library([ 'JAVA','Python','Javascript','HTML basic','PHP'],"codebookslibrary")
    while(True):
        print(f"welcome to the {code.name} .Enter your choice")
        print("1. Dispaly Books")
        print("2. lend a Book")
        print("3. return a Book")
        user_choice = int(input())
        
        if user_choice not in [1,2,3]:
            print("please enter a valid option")
            continue
        else:
            user_choice = int(user_choice)
        
        if user_choice == 1:
            code.displayBooks()
        
        elif user_choice == 2:
            book = input("enter the book name which you want to lend ")
            user = input("Enter your name ")
            code.lendBook(user,book)
        
        elif user_choice == 3:
            book = input("Enter the book name which u want to return ")
            code.returnBook(book)
        else:
            print("not valid option")
        
        print("press q to quit and c to continue") 
        user_choice2 = ""
#         while(user_choice2 !="c" and user_choice2 !="q"):
        user_choice2 = input()
        if user_choice2 =="q":
            exit()
        if user_choice2 =="c":
            continue
# Out:
# welcome to the codebookslibrary .Enter your choice
# 1. Dispaly Books
# 2. lend a Book
# 3. return a Book
# 1
# we have many books in library : codebookslibrary
# JAVA
# Python
# Javascript
# HTML basic
# PHP
# press q to quit and c to continue
# c
# welcome to the codebookslibrary .Enter your choice
# 1. Dispaly Books
# 2. lend a Book
# 3. return a Book
# 2
# enter the book name which you want to lend Python
# Enter your name misbah
# lender-book database has been updated. you can take it
# press q to quit and c to continue
# c
# welcome to the codebookslibrary .Enter your choice
# 1. Dispaly Books
# 2. lend a Book
# 3. return a Book
# 2
# enter the book name which you want to lend Python
# Enter your name zikra
# book is already taken by: {'misbah'}
# press q to quit and c to continue
# c
# welcome to the codebookslibrary .Enter your choice
# 1. Dispaly Books
# 2. lend a Book
# 3. return a Book
# 3
# Enter the book name which u want to return Python
# ...
